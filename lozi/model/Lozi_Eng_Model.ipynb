# %% [markdown]
# # OpenNMT
# # Mahcine Traslation

# %% [markdown]
# ### This modules creates a simple openNMT model for text-to-text translation
# ### with the nyanja-english corpus named as ny-en corpus

# %%
# mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# installing the required libraries
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 226 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 57 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 16.9 MB 72.0 MB/s
# ...
#      |████████████████████████████████| 116 kB 64.4 MB/s
# ...
#      |████████████████████████████████| 73 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 55.2 MB/s
# ...
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
# ...

# %%
# preparing the data
# !cd drive/"My Drive"/machine-translation/Machine_Translation/ny-en

# %%
# !head -n 2 drive/"My Drive"/machine-translation/Machine_Translation/ny-en/src-train.txt
# !head -n 2 drive/"My Drive"/machine-translation/Machine_Translation/ny-en/tgt-train.txt
# !head -n 2 drive/"My Drive"/machine-translation/Machine_Translation/ny-en/src-val.txt
# !head -n 2 drive/"My Drive"/machine-translation/Machine_Translation/ny-en/tgt-val.txt
# Out:
# ENGLISH SENTENCE
# Several men in hard hats are operating a giant pulley system .
# NYANJA SENTENCE
# Azibambo ambiri mu manyuma olimba akusewenzera pa  cisulo zokoka cacikulu.
# ENGLISH SENTENCE
# A young child runs down a gravel road covered with dead leaves .
# NYANJA SENTENCE
# Mwana wamng'ono wathamanga mumseu wamiyala odzadzidwa ndi mayani akufa.

# %%
# !touch drive/"My Drive"/machine-translation/Machine_Translation/ny-en/run/example.vocab.src
# !touch drive/"My Drive"/machine-translation/Machine_Translation/ny-en/run/example.vocab.tgt

# %%
# building the vocab(s) necessary for training the model
# !onmt_build_vocab -config drive/"My Drive"/machine-translation/Machine_Translation/ny-en/ny_en.yaml -n_sample 10000
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 71, in main
#     build_vocab_main(opts)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 23, in build_vocab_main
#     ArgumentParser.validate_prepare_opts(opts, build_vocab_only=True)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/utils/parse.py", line 194, in validate_prepare_opts
#     cls._validate_data(opt)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/utils/parse.py", line 55, in _validate_data
#     cls._validate_file(path_src, info=f'{cname}/path_src')
#   File "/usr/local/lib/python3.7/dist-packages/onmt/utils/parse.py", line 18, in _validate_file
#     raise IOError(f"Please check path of your {info} file!")
# OSError: Please check path of your corpus_1/path_src file!

# %%
# the following code will run on a single GPU: world_size 1 & gpu_ranks [3]
# !onmt_train -config drive/"My Drive"/machine-translation/Machine_Translation/ny-en/ny_en.yaml

# %%
# Performing the translations
# !onmt_translate -model drive/"My Drive"/machine-translation/Machine_Translation/ny-en/run/model_step_1000.pt -src drive/"My Drive"/machine-translation/Machine_Translation/ny-en/src-test.txt -output drive/"My Drive"/machine-translation/Machine_Translation/ny-en/pred_1000.txt -gpu 0 -verbose

# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install -r requirements.opt.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.opt.txt'

# %%
# !head -n 2 lz-en/src-train.txt
# !head -n 2 lz-en/tgt-train.txt
# !head -n 2 lz-en/src-val.txt
# !head -n 2 lz-en/tgt-val.txt
# !head -n 2 lz-en/src-test.txt
# !head -n 2 lz-en/tgt-test.txt
# Out:
# ENGLISH SENTENCES
# A man is carrying a baby in a pouch to his chest is helping a small boy walk across a log by holding his hand .
# LOZI TRANSLATIONS
# Muuna upepile mbututu mwa kananulelo kaka fa sifuba sahae inge a tusa muchaha wamwanana kuzamaya
# ENGLISH SENTENCES
# A man wearing a red shirt sits on a cement bench and reads the paper .
# LOZI TRANSLATIONS
# muuna yatinile hembe yefubelu uina fa sipula sa samende inze abala pepa
# ENGLISH SENTENCES
# Watchers of a parade remain seated while others walk the street where the debris remains .
# LOZI TRANSLATIONS
# "batu bababuha babachaula , bainzii babamwi bazamaya mwa mukwakwa"

# %%
# !onmt-build-vocab --size 5000 --save_vocab ny-en/src-vocab.vocab ny-en/src-train.txt
# !onmt-build-vocab --size 5000 --save_vocab ny-en/tgt-vocab.vocab ny-en/tgt-train.txt

# %%
# !onmt_build_vocab -config lz-en/lz-en.yml -n_sample 1000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-10-15 21:53:35,748 INFO] Counter vocab from 1000 samples.
# [2022-10-15 21:53:35,748 INFO] Build vocab on 1000 transformed examples/corpus.
# [2022-10-15 21:53:35,756 INFO] corpus_1's transforms: TransformPipe()
# [2022-10-15 21:53:35,857 INFO] Counters src:2615
# [2022-10-15 21:53:35,857 INFO] Counters tgt:2959
# Traceback (most recent call last):
#   File "/usr/local/bin/onmt_build_vocab", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 71, in main
#     build_vocab_main(opts)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 55, in build_vocab_main
#     save_counter(src_counter, opts.src_vocab)
#   File "/usr/local/lib/python3.7/dist-packages/onmt/bin/build_vocab.py", line 44, in save_counter
#     check_path(save_path, exist_ok=opts.overwrite, log=logger.warning)
# ...

# %%
# !onmt_train -config lz-en/lz-en.yml
# Out:
# [2022-10-15 21:53:41,398 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-10-15 21:53:41,399 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-10-15 21:53:41,399 INFO] Missing transforms field for valid data, set to default: [].
# [2022-10-15 21:53:41,399 INFO] Parsed 2 corpora from -data.
# [2022-10-15 21:53:41,399 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-10-15 21:53:41,399 INFO] Loading vocab from text file...
# [2022-10-15 21:53:41,399 INFO] Loading src vocabulary from lz-en/run/example.vocab.src
# [2022-10-15 21:53:41,403 INFO] Loaded src vocab has 2615 tokens.
# [2022-10-15 21:53:41,404 INFO] Loading tgt vocabulary from lz-en/run/example.vocab.tgt
# [2022-10-15 21:53:41,409 INFO] Loaded tgt vocab has 2959 tokens.
# [2022-10-15 21:53:41,410 INFO] Building fields with vocab in counters...
# [2022-10-15 21:53:41,414 INFO]  * tgt vocab size: 2963.
# ...

# %%
# !onmt_translate -model lz-en/run/model_step_1000.pt -src lz-en/src-test.txt -output lz-en/lozi_test_pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# SENT 1799: ['"Several', 'people', 'stand', 'in', 'line', 'at', 'what', 'appears', 'to', 'be', 'a', 'park', 'for', 'a', 'water', 'fountain', ',', 'vendor', ',', 'lavatory', 'or', 'something', 'of', 'the', 'sort', '."']
# PRED 1799: bana baba ñata, kukopanyeleza niyatinile kuwani yesweu batalimezi mukwakwa opayehile"
# PRED SCORE: -4.8603
#
# [2022-10-15 21:55:03,210 INFO]
# SENT 1800: ['"A', 'female', 'with', 'blond-hair', ',', 'wearing', 'blue', 'jeans', ',', 'walking', 'past', 'a', 'music', 'store', 'and', 'tall', ',', 'beige', 'building', 'which', 'has', 'tall', 'glass', 'doors', '."']
# PRED 1800: musali yamwa litino zakutapela za mubala oswana sina wa mai mi yomumwi, njamala yesweu"
# PRED SCORE: -7.1408
#
# [2022-10-15 21:55:03,289 INFO]
# SENT 1801: ['"A', 'young', 'boy', 'holding', 'a', 'toy', 'stands', 'on', 'a', 'stool', 'in', 'the', 'shower', ',', 'looking', 'at', 'the', 'camera', '."']
# ...

# %%
# !onmt_release_model -model lz-en/run/model_step_1000.pt -output lz-en/run/model_step_1000_release.pt
# Out:
# usage: onmt_release_model [-h] --model MODEL --output OUTPUT
#                           [--format {pytorch,ctranslate2}]
#                           [--quantization {int8,int16,float16,int8_float16}]
# onmt_release_model: error: unrecognized arguments: lz-en/run/model_step_1000.pt lz-en/run/model_step_1000_release.pt
